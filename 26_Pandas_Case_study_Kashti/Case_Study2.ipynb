# %% [markdown]
# > #  Cereals Total production in Pakistan

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data1= pd.read_csv("FAOSTAT_Pak_Production.csv")
data1.describe()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       180 non-null    object
#  1   Domain            180 non-null    object
#  2   Area Code         180 non-null    int64
#  3   Area              180 non-null    object
#  4   Element Code      180 non-null    int64
#  5   Element           180 non-null    object
#  6   Item Code         180 non-null    int64
#  7   Item              180 non-null    object
#  8   Year Code         180 non-null    int64
#  9   Year              180 non-null    int64
#  10  Unit              180 non-null    object
#  11  Value             180 non-null    int64
#  12  Flag              180 non-null    object
#  13  Flag Description  180 non-null    object
# dtypes: int64(6), object(8)
# memory usage: 19.8+ KB

# %%
data1.head(5)
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
# 1          5419           Yield       1717  Cereals, Total       1961  1961
# 2          5510      Production       1717  Cereals, Total       1961  1961
# 3          5312  Area harvested       1717  Cereals, Total       1962  1962
# 4          5419           Yield       1717  Cereals, Total       1962  1962
#
#      Unit    Value Flag                                   Flag Description
# ...

# %%
# data1.iloc[2,0]  # 3rd row 1st coloumn
# data1.iloc[:,5]    # all rows 5th columns

# %%
data1.iloc[1,:]    # 1st rows all columns
len(data1)
# Out:
# 180

# %%
data1.drop(["Flag","Flag Description"],axis=1).head()
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
# 1          5419           Yield       1717  Cereals, Total       1961  1961
# 2          5510      Production       1717  Cereals, Total       1961  1961
# 3          5312  Area harvested       1717  Cereals, Total       1962  1962
# 4          5419           Yield       1717  Cereals, Total       1962  1962
#
#      Unit    Value
# 0      ha  7858558
# 1   hg/ha     8564
# 2  tonnes  6729680
# 3      ha  8090856
# ...

# %%
data1.drop(["Flag","Flag Description"],axis=1).head(1)
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
#
#   Unit    Value
# 0   ha  7858558

# %%
data1.groupby(["Element"]).mean()
# Out:
#                 Area Code  Element Code  Item Code  Year Code    Year  \
# Element
# Area harvested      165.0        5312.0     1717.0     1990.5  1990.5
# Production          165.0        5510.0     1717.0     1990.5  1990.5
# Yield               165.0        5419.0     1717.0     1990.5  1990.5
#
#                        Value
# Element
# Area harvested  1.147575e+07
# Production      2.333722e+07
# Yield           1.932600e+04

# %%
data1.groupby(["Year Code","Element"]).mean().head(20)
# Out:
#                           Area Code  Element Code  Item Code    Year  \
# Year Code Element
# 1961      Area harvested      165.0        5312.0     1717.0  1961.0
#           Production          165.0        5510.0     1717.0  1961.0
#           Yield               165.0        5419.0     1717.0  1961.0
# 1962      Area harvested      165.0        5312.0     1717.0  1962.0
#           Production          165.0        5510.0     1717.0  1962.0
#           Yield               165.0        5419.0     1717.0  1962.0
# 1963      Area harvested      165.0        5312.0     1717.0  1963.0
#           Production          165.0        5510.0     1717.0  1963.0
#           Yield               165.0        5419.0     1717.0  1963.0
# 1964      Area harvested      165.0        5312.0     1717.0  1964.0
#           Production          165.0        5510.0     1717.0  1964.0
#           Yield               165.0        5419.0     1717.0  1964.0
# ...

# %%
data1.head()
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
# 1          5419           Yield       1717  Cereals, Total       1961  1961
# 2          5510      Production       1717  Cereals, Total       1961  1961
# 3          5312  Area harvested       1717  Cereals, Total       1962  1962
# 4          5419           Yield       1717  Cereals, Total       1962  1962
#
#      Unit    Value Flag                                   Flag Description
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x="Year",y="Value",hue="Element",data=data1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x="Year",y="Value",hue="Flag",data=data1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
data1.head()
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
# 1          5419           Yield       1717  Cereals, Total       1961  1961
# 2          5510      Production       1717  Cereals, Total       1961  1961
# 3          5312  Area harvested       1717  Cereals, Total       1962  1962
# 4          5419           Yield       1717  Cereals, Total       1962  1962
#
#      Unit    Value Flag                                   Flag Description
# ...

# %%
data1[data1["Value"]>9000].groupby(["Area","Element","Year"]).head()
# Out:
#     Domain Code                        Domain  Area Code      Area  \
# 0           QCL  Crops and livestock products        165  Pakistan
# 2           QCL  Crops and livestock products        165  Pakistan
# 3           QCL  Crops and livestock products        165  Pakistan
# 5           QCL  Crops and livestock products        165  Pakistan
# 6           QCL  Crops and livestock products        165  Pakistan
# ..          ...                           ...        ...       ...
# 175         QCL  Crops and livestock products        165  Pakistan
# 176         QCL  Crops and livestock products        165  Pakistan
# 177         QCL  Crops and livestock products        165  Pakistan
# 178         QCL  Crops and livestock products        165  Pakistan
# 179         QCL  Crops and livestock products        165  Pakistan
#
#      Element Code         Element  Item Code            Item  Year Code  Year  \
# 0            5312  Area harvested       1717  Cereals, Total       1961  1961
# ...
