# %% [markdown]
# # Seaborn Libraries
# ## *numpy*
# ## *scipy*
# ## *pandas*
# ## *matplotlib*

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("iris")
print(phool)
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.title("Phoolo ka Plot")
plt.show()
sns.lineplot(data=phool)
plt.title("Phoolo ka Akatha Plot")
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("iris")
plt.figure(figsize=(3, 4))
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.show()
sns.barplot(x="species",y="sepal_width", data=phool)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
phool=sns.load_dataset("iris")
plt.figure(figsize=(3, 4))
sns.lineplot(x="sepal_length",y="sepal_width", data=phool)
plt.show()
sns.barplot(x="species",y="sepal_width", data=phool, color="black"b)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="fare",y="class",hue="sex", data=kashti, saturation=3)
plt.xlim(0,120)
plt.title("Fare of population")
plt.show()

# sns.barplot(x="class", y="fare", hue="sex", data=kashti, estimator=mean, saturation=1)
# plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
kashti=sns.load_dataset("titanic")
kashti
sns.barplot(x="class",y="fare", data=kashti, saturation=3, linewidth=2, facecolor=(1,0.3,0.4,0.5), edgecolor="0",errcolor="0")
# plt.xlim(0,120)
plt.title("Fare of population")
plt.show()

# %%
import seaborn as sns
seaborn.set(style="whitegrid")
kashti=sns.load_dataset("titanic")
sns.boxplot(x="class",y="fare",data=kashti)
plt.ylim(0,150)
# Out:
# (0.0, 150.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
seaborn.set(style="ticks")
tip=sns.load_dataset('tips')
print(tip)
sns.boxplot(x=tip["total_bill"])
plt.show()
sns.boxplot(x=tip["total_bill"], y= tip["day"],data=tip)
plt.show()
sns.boxplot(x= tip["day"],y=tip["total_bill"],data=tip)
plt.show()
# sns.barplot(x="sex",y="tip",data=tip)
# plt.show()
# seaborn.boxplot(y=tip["total_bill"])

sns.boxplot(x="sex",y="tip",hue= "smoker",data=tip)
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
kashti=sns.load_dataset("titanic")
print(kashti)
kashti.head()
p1=sns.boxplot(x="survived", y="age",
               meanprops={"marker":"+",
                          "markeredgecolor": "blue"
               
               },
               showmeans=True, data=kashti)
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
kashti=sns.load_dataset("titanic")
print(kashti)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# Import Data File 
d= pd.read_excel("Book1.xlsx")
# print(d)
sns.barplot(y="Total Acre",x="Education",data=d)
plt.show()
d.head()
x=sns.boxplot(x=d["Own Acres"], showmeans=True)
